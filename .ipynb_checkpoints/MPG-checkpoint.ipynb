# %%
import pandas as pd
import numpy
import xlrd
import re
import numpy as np
import matplotlib.pyplot as plt


pd.set_option('display.max_columns', 500)

# %%
sheets = list(range(1,20))


xls = xlrd.open_workbook('MPG_data/Source/Stats MPG-saison6MPG.xlsx', on_demand=True)
sheet_names= xls.sheet_names()
data = pd.DataFrame()
o = 7

for n in sheets :   
    temp_data = pd.read_excel('MPG_data/Source/Stats MPG-saison6MPG.xlsx',skiprows = 6,sheet_name = n+1,encoding = 'latin-1')
    pattern = re.compile("^J")

    # apply regex
    num_match = len(temp_data.columns) - 7 
    headers = ['Poste','Cote','Nom','Titula','Entres','Buts','Moyenne']
    for match in range(1,num_match+1) :
        headers.append('Match{}'.format(match))
        match += 1

    # set new list as column headers
    temp_data.columns = headers
    
    temp_data['team'] = sheet_names[n+1]
    temp_data.drop(temp_data.tail(1).index,inplace=True)
    
    
    
    data = pd.concat([data,temp_data])

print(str(num_match)+ ': match loaded')

matches = [col for col in data.columns if 'Match' in col]


data['var'] = data[data.columns.intersection(matches)].var(axis=1)
# Out:
# 38: match loaded

# %%
data.head()
# Out:
#   Poste  Cote                Nom  Titula  Entres  Buts   Moyenne  Match1  \
# 0     G  21.0      Lopes Anthony    34.0     NaN   NaN  5.514706     NaN
# 1     G   6.0   Gorgelin Mathieu     4.0     NaN   NaN  5.750000     6.0
# 2     D   7.0       Morel Jérémy    12.0     NaN   NaN  5.041667     6.0
# 3     D   8.0             Rafael    11.0     7.0  (-1)  4.972222     NaN
# 4     D   3.0  Yanga-Mbiwa Mapou     NaN     NaN   NaN       NaN     NaN
#
#    Match2  Match3 Match4  Match5  Match6  Match7  Match8  Match9  Match10  \
# 0     NaN     5.5    4.5     5.0     4.5     7.0     5.5     4.0      7.0
# 1     5.0     NaN    NaN     NaN     NaN     NaN     NaN     NaN      NaN
# 2     5.0     5.5    NaN     NaN     NaN     7.0     5.0     3.0      NaN
# 3     5.0     5.5      5     4.5     NaN     6.5     5.0     5.5      NaN
# 4     NaN     NaN    NaN     NaN     NaN     NaN     NaN     NaN      NaN
#
#    Match11  Match12  Match13  Match14  Match15  Match16  Match17  Match18  \
# 0      6.0      5.0      5.0      7.0      5.5      4.5      5.0      5.5
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      3.5      NaN      NaN      4.0      4.5      NaN
# 3      5.0      5.0      5.0      4.5      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Match19  Match20  Match21  Match22  Match23  Match24  Match25  Match26  \
# 0      5.5      5.5      8.0      6.0      7.0      5.5      5.5      5.0
# 1      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Match27  Match28  Match29  Match30  Match31  Match32  Match33  Match34  \
# 0      5.0      5.5      NaN      6.0      3.5      5.0      4.5      4.5
# 1      NaN      NaN      5.0      NaN      NaN      NaN      NaN      NaN
# 2      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
# 3      5.5      NaN      4.5      5.5      2.5      5.0      NaN      NaN
# 4      NaN      NaN      NaN      NaN      NaN      NaN      NaN      NaN
#
#    Match35  Match36  Match37  Match38 team       var
# 0      5.0      8.0      6.0      NaN   OL  1.083111
# 1      NaN      NaN      NaN      7.0   OL  0.916667
# 2      NaN      6.0      6.0      5.0   OL  1.339015
# 3      NaN      5.0      5.0      NaN   OL  0.602124
# 4      NaN      NaN      NaN      NaN   OL       NaN

# %%
## over7
matches = [col for col in data.columns if 'Match' in col]

histo = pd.melt(data,id_vars=['Nom'], value_vars=matches)

# %%
histo.head()
# Out:
#                  Nom variable value
# 0      Lopes Anthony   Match1   NaN
# 1   Gorgelin Mathieu   Match1     6
# 2       Morel Jérémy   Match1     6
# 3             Rafael   Match1   NaN
# 4  Yanga-Mbiwa Mapou   Match1   NaN

# %%
def player_hist(data = histo, name = 'Mbappé Kylian'):
    temp_player = data[data['Nom'] == name]
    plt.plot(temp_player['value'])
    return temp_player

temp = player_hist()
temp
# Out:
#                  Nom variable value
# 55     Mbappé Kylian   Match1   NaN
# 616    Mbappé Kylian   Match2   7.5
# 1177   Mbappé Kylian   Match3     7
# 1738   Mbappé Kylian   Match4     7
# 2299   Mbappé Kylian   Match5   NaN
# 2860   Mbappé Kylian   Match6   NaN
# 3421   Mbappé Kylian   Match7   NaN
# 3982   Mbappé Kylian   Match8     7
# 4543   Mbappé Kylian   Match9     9
# 5104   Mbappé Kylian  Match10     7
# 5665   Mbappé Kylian  Match11   6.5
# 6226   Mbappé Kylian  Match12     7
# 6787   Mbappé Kylian  Match13     6
# 7348   Mbappé Kylian  Match14   NaN
# 7909   Mbappé Kylian  Match15     6
# 8470   Mbappé Kylian  Match16   5.5
# 9031   Mbappé Kylian  Match17     7
# 9592   Mbappé Kylian  Match18     7
# 10153  Mbappé Kylian  Match19     6
# 10714  Mbappé Kylian  Match20     7
# 11275  Mbappé Kylian  Match21     9
# 11836  Mbappé Kylian  Match22     8
# 12397  Mbappé Kylian  Match23   5.5
# 12958  Mbappé Kylian  Match24     5
# 13519  Mbappé Kylian  Match25     6
# 14080  Mbappé Kylian  Match26     7
# 14641  Mbappé Kylian  Match27     7
# 15202  Mbappé Kylian  Match28   NaN
# 15763  Mbappé Kylian  Match29     7
# 16324  Mbappé Kylian  Match30     6
# 16885  Mbappé Kylian  Match31     5
# 17446  Mbappé Kylian  Match32   4.5
# 18007  Mbappé Kylian  Match33     8
# 18568  Mbappé Kylian  Match34   NaN
# 19129  Mbappé Kylian  Match35   NaN
# 19690  Mbappé Kylian  Match36   NaN
# 20251  Mbappé Kylian  Match37     8
# 20812  Mbappé Kylian  Match38     6

# %%
list(temp['value'])[1]
# Out:
# 7.5

# %%
data.to_csv('MPG_data/players.csv')
histo.to_csv('MPG_data/historic.csv')

# %%
players = pd.read_csv('MPG_Data/players.csv',encoding = 'latin-1')

# %%
print(players.Nom.unique())
# Out:
# ['LopesÂ\xa0Anthony' 'GorgelinÂ\xa0Mathieu' 'MorelÂ\xa0JÃ©rÃ©my' 'Rafael'
#  'Yanga-MbiwaÂ\xa0Mapou' 'MarÃ§al' 'Marcelo' 'MendyÂ\xa0Ferland'
#  'Dubois LÃ©o' 'Denayer Jason' 'Solet Oumar' 'TeteÂ\xa0Kenny'
#  'FerriÂ\xa0Jordan' 'TousartÂ\xa0Lucas' 'NDombeleÂ\xa0Tanguy'
#  'Pape Cheikh' 'Terrier Martin' 'AouarÂ\xa0Houssem' 'DepayÂ\xa0Memphis'
#  'Mariano' 'TraorÃ©Â\xa0Bertrand' 'FekirÂ\xa0Nabil' 'Gouiri Amine'
#  'Dembele Moussa' 'Pintor Lenny' 'Fekir Yassin' 'CornetÂ\xa0Maxwel'
#  'AreolaÂ\xa0Alphonse' 'Buffon Gianluigi' 'Thiago Silva' 'Marquinhos'
#  'Dani Alves' 'KimpembeÂ\xa0Presnel' 'KurzawaÂ\xa0Layvin' 'Dagba Colin'
#  'Kehrer Thilo' 'Bernat Juan' 'Rimane Kevin' 'Mbe Soh LoÃ¯c'
#  'MeunierÂ\xa0Thomas' 'VerrattiÂ\xa0Marco' 'RabiotÂ\xa0Adrien'
#  'Di MarÃ\xadaÂ\xa0Ã\x81ngel' 'NkunkuÂ\xa0Christopher' 'Lass Diarra'
#  'DraxlerÂ\xa0Julian' 'Lo CelsoÂ\xa0Giovani' 'Bernede Antoine'
#  'Choupo-Moting Eric Maxim' 'Paredes Leandro' "N'Soki Stanley"
#  'CavaniÂ\xa0Edinson' 'Diaby Moussa' 'Neymar' 'Guclu MÃ©tÃ©han'
#  'MbappÃ©Â\xa0Kylian' 'Weah Timothy' 'CardinaleÂ\xa0Yoan'
#  'BenÃ\xadtezÂ\xa0Walter' 'HassenÂ\xa0Mouez' 'BoscagliÂ\xa0Olivier'
#  'SarrÂ\xa0Malang' 'Dante' 'JalletÂ\xa0Christophe' 'Coly Racine'
#  'Herelle Christophe' 'Atal Youcef' 'Pelmard Andy' 'BurnerÂ\xa0Patrick'
#  'MakengoÂ\xa0Jean-Victor' 'WalterÂ\xa0Remi' 'CyprienÂ\xa0Wylan'
#  'Lees-MelouÂ\xa0Pierre' 'TamezeÂ\xa0Adrien' 'SrarfiÂ\xa0Bassem'
#  'Saint-MaximinÂ\xa0Allan' 'MahouÂ\xa0Hicham' 'Danilo' 'Sylvestre Eddy'
#  'Wade Paul' 'Jaziri Assil' 'Sacko Ihsan' 'Le BihanÂ\xa0Mickael'
#  'BalotelliÂ\xa0Mario' 'Diaby Mohamed Lamine' 'Maolida Myziane'
#  'Pelican Maxime' 'Pedro Brazao' 'GanagoÂ\xa0Ignatius' nan
#  'RuffierÂ\xa0StÃ©phane' 'MoulinÂ\xa0Jessy' 'PerrinÂ\xa0Loic'
#  'PolomatÂ\xa0Pierre-Yves' 'Saliba William' 'Gabriel Silva'
#  'Subotic Neven' 'Kolodziejczak TimothÃ©e' 'Panos Mickael' 'Fofana Wesley'
#  'Debuchy Mathieu' 'HamoumaÂ\xa0Romain' 'SelnaesÂ\xa0Ole'
#  'DioussÃ©Â\xa0Assane' 'Khazri Wahbi' 'Camara Mahdi' 'Nordin Arnaud'
#  'Cabella RÃ©my' 'Salibur Yannis' 'Rocha Santos Kenny'
#  'AÃ¯t Bennasser Youssef' 'Vada Valentin' "M'Vila Yann"
#  'Monnet-PaquetÂ\xa0KÃ©vin' 'DionyÂ\xa0Lois' 'BericÂ\xa0Robert'
#  'Abi Charles' 'Ghezali Lamine' 'Gueye Makhtar' 'JakubechÂ\xa0Adam'
#  'MaignanÂ\xa0Mike' 'KoffiÂ\xa0Kouakou' 'SoumaoroÂ\xa0Adama' 'IÃ© Edgar'
#  'Kone Youssouf' 'Dabila Kouadio' 'Zeki Celik Mehmet' 'JosÃ© Fonte'
#  'Gabriel' 'Pied JÃ©rÃ©my' 'Reinildo' 'Ballo-ToureÂ\xa0Fode'
#  'Thiago Mendes' 'Xeka' 'FarajÂ\xa0Imad' 'BahlouliÂ\xa0Fares'
#  'Soumare Boubakary' 'Bamba Jonathan' 'Jonathan Ikone' 'Zekaj Arton'
#  'Thiago Maia' 'Luiz Araujo' 'Rui Fonte' 'Rafael Leao' 'PepeÂ\xa0Nicolas'
#  'Mothiba Lebo' 'Remy LoÃ¯c' 'BenziaÂ\xa0Yassine' 'CostilÂ\xa0Benoit'
#  'Poussin Gaetan' 'PriorÂ\xa0Jerome' 'PoundjÃ©Â\xa0Maxime'
#  'SabalyÂ\xa0Youssouf' 'LewczukÂ\xa0Igor' 'GajicÂ\xa0Milan'
#  'Carrique Thomas' 'KoundÃ© Jules' 'Baysse Paul' 'Pablo' 'Palencia Sergi'
#  'Lauray Alexandre' 'Cissokho Till' 'Jovanovic Vukasin'
#  'PlasilÂ\xa0Jaroslav' 'VadaÂ\xa0Valentin' 'LeragerÂ\xa0Lukas' 'OtÃ¡vio'
#  'Youssouf Zaydou' 'Tchouameni Aurelien' 'Basic Toma' 'Adli Yacine'
#  'Lottin Albert' 'Benrahou Yassine' 'Trichard Driss'
#  'SankharÃ©Â\xa0Younousse' 'LabordeÂ\xa0Gaetan' 'KamanoÂ\xa0Francois'
#  'de PrevilleÂ\xa0Nicolas' 'Kalu Samuel' 'Cornelius Andreas'
#  'Karamoh Yann' 'Maja Josh' 'Briand Jimmy' 'LecomteÂ\xa0Benjamin'
#  'Bertaud Dimitry' 'CongrÃ©Â\xa0Daniel' 'Hilton' 'Pedro Mendes'
#  'PoatyÂ\xa0Morgan' 'AguilarÂ\xa0Ruben' 'Cozza Nicolas' 'Le Tallec Damien'
#  'PassiÂ\xa0Bryan' 'Suarez Mathias' 'Ambroise Oyongo' 'Ristic Mihailo'
#  'LasneÂ\xa0Paul' 'SkhiriÂ\xa0Ellyes' 'DollyÂ\xa0Keagan'
#  'PÃ\xadrizÂ\xa0Facundo' 'Junior Sambia' 'Mollet Florent' 'Ammour Yannis'
#  'Boutobba Bilal' 'SansonÂ\xa0Killian' 'CamaraÂ\xa0Souleymane'
#  'SioÂ\xa0Giovanni' 'Laborde Gaetan' 'Skuletic Petar' 'Delort Andy'
#  'Reynet Baptiste' 'GoicoecheaÂ\xa0Mauro' 'AmianÂ\xa0Kelvin'
#  'JullienÂ\xa0Christopher' 'SyllaÂ\xa0Issiaga' 'MichelinÂ\xa0Clement'
#  'Fortes Steven' 'Moreira Steven' 'Diakite Bafode' 'Shoji Gen'
#  'MoubandjeÂ\xa0FranÃ§ois' 'BodigerÂ\xa0Yann' 'SangarÃ©Â\xa0Ibrahim'
#  'CahuzacÂ\xa0Yannick' 'Manu Garcia' 'Bostock John' 'DosseviÂ\xa0Mathieu'
#  'Todibo Jean-Clair' 'Sidibe Kalidou' 'Kone Kouadio'
#  "N'Goumou Minpol Nathan" 'Mbia StÃ©phane' 'DurmazÂ\xa0Jimmy'
#  'JeanÂ\xa0Corentin' 'GradelÂ\xa0Max' 'El Mokeddem Hakim' 'Mubele Firmin'
#  'Leya Iseka' 'SanogoÂ\xa0Yaya' 'DialloÂ\xa0Abdoulaye' 'KoubekÂ\xa0Tomas'
#  'GertmonasÂ\xa0Edvinas' 'DanzÃ©Â\xa0Romain' 'Mexer' 'TraorÃ© Hamari'
#  'BaalÂ\xa0Ludovic' 'ZeffaneÂ\xa0Mehdi' 'BensebainiÂ\xa0Ramy'
#  'NyamsiÂ\xa0Gerzino' 'Da Silva Damien' 'Doumbia Souleyman' 'Boey Sacha'
#  'Gelin Jeremy' 'HunouÂ\xa0Adrien' 'AndrÃ©Â\xa0Benjamin'
#  'BourigeaudÂ\xa0Benjamin' 'JanvierÂ\xa0Nicolas'
#  'Lea SilikiÂ\xa0James Edward' 'Grenier ClÃ©ment' 'Ben Arfa Hatem'
#  'Poha Denis' 'Johansson Jakob' 'Camavinga Eduardo' 'Del Castillo Romain'
#  'Siebatcheu Jordan' 'Ismaila Sarr' "Niang M'Baye" 'Lauriente Armand'
#  'Sakho Diafra' 'DupÃ©Â\xa0Maxime' 'TatarusanuÂ\xa0Ciprian'
#  'OllieroÂ\xa0Alexandre' 'DjidjiÂ\xa0Koffi' 'KwatengÂ\xa0Enock'
#  'WalongwaÂ\xa0Anthony' 'Diego Carlos' 'Lucas Lima' 'Miazga Matt'
#  'Kara Mbodji Serigne Modou' 'Fabio' 'Charles TraorÃ©' 'Edgar IÃ©'
#  'Basila Thomas' 'PalloisÂ\xa0Nicolas' 'TourÃ© Abdoulaye'
#  'RongierÂ\xa0Valentin' 'MoutoussamyÂ\xa0Samuel' 'Andrei Girotto'
#  'KrhinÂ\xa0Rene' 'Kayembe Joris' 'Dabo Abdoulaye' 'Boschilia Gabriel'
#  'Lucas Evangelista' 'Alexis Alegue' 'Limbombe Anthony' 'Louza Imran'
#  'Eysseric Valentin' 'Kolo Muani Randal' 'SalaÂ\xa0Emiliano'
#  'Mance Antonio' 'Youan Thody Elie' 'Kalifa Coulibaly' 'Majeed Waris'
#  'BenaglioÂ\xa0Diego' 'SubasicÂ\xa0Danijel' 'SyÂ\xa0Seydou'
#  'RaggiÂ\xa0Andrea' 'Jemerson' 'TourÃ©Â\xa0Almamy' 'Serrano Julien'
#  'SidibeÂ\xa0Djibril' 'GlikÂ\xa0Kamil' 'Pierre Gabriel Ronael'
#  'Barreca Antonio' "N'DoramÂ\xa0Kevin" 'Badiashile BenoÃ®t'
#  'Biancone Giulian' 'Naldo' 'Ballo-Toure Fode' 'Henrichs Benjamin'
#  'Adama TraorÃ©' 'Rony Lopes' 'Aholou Jean Eudes' 'Diop Sofiane'
#  'Chadli Nacer' 'Golovin Aleksandr' 'PelÃ©' 'Massengo Han-Noah'
#  'Faivre Romain' 'FÃ\xa0bregas Cesc' 'Vainqueur William' 'Adrien Silva'
#  'Nkoudou Georges-KÃ©vin' 'TielemansÂ\xa0Youri' 'Falcao'
#  'JoveticÂ\xa0Stevan' 'Pellegri Pietro' 'Mboula Jordi' 'Grandsir Samuel'
#  'Geubbels Willem' 'Isidor Wilson' 'Carlos Vinicius' 'Gelson Martins'
#  'Sylla Moussa' 'ReuletÂ\xa0Paul' 'SambaÂ\xa0Brice' 'DjikuÂ\xa0Alexander'
#  'Gradit Jonathan' 'GenevoisÂ\xa0Romain' 'GuilbertÂ\xa0Frederic'
#  'MbengueÂ\xa0Adama' 'Armougom YoÃ«l' 'Zahary Younn' 'Imorou Emmanuel'
#  'Fajr Faycal' 'DiomandeÂ\xa0Ismael' 'PeetersÂ\xa0Stef' 'OnianguÃ© Prince'
#  'RepasÂ\xa0Jan' 'Khaoui Saif-Eddine' 'SankohÂ\xa0Baissama' 'Joseph Evans'
#  'Ndom Aly' 'Deminguet Jessy' 'Tchokounte Malik' 'Stavitski Timo'
#  'Ninga Casimir' 'Bammou Yacine' 'Beauvue Claudio' 'Moussaki Herman'
#  'Crivelli Enzo' 'JohnssonÂ\xa0Karl-Johan' 'Caillard Marc-AurÃ¨le'
#  'SorbonÂ\xa0JÃ©rÃ©my' 'IkokoÂ\xa0Jordan' 'Pedro Rebocho'
#  'Eboa EboaÂ\xa0Felix' 'TabanouÂ\xa0Franck' 'TraorÃ© Cheick'
#  'Koita Djegui' 'Johan Larsson' 'Djilobodji Papy' 'KerbratÂ\xa0Christophe'
#  'SaliburÂ\xa0Yannis' 'BenezetÂ\xa0Nicolas' 'CocoÂ\xa0Marcus'
#  'BlasÂ\xa0Ludovic' 'DidotÂ\xa0Ã\x89tienne' 'PhiriÂ\xa0Lebogang'
#  'Fofana Guessouma' 'Ndong Didier' 'Merghem Mehdi' 'Carnot Louis'
#  'DeauxÂ\xa0Lucas' 'ThuramÂ\xa0Marcus' "N'Gbakoto Yeni" 'Roux Nolan'
#  'Julan NathaÃ«l' 'Phaeton Matthias' 'Mendy Alexandre' 'Rodelin Ronny'
#  'Boucher Zacharie' 'Butelle Ludovic' 'ThomasÂ\xa0Romain'
#  'TraorÃ©Â\xa0Ismael' 'AndreuÂ\xa0Yoann' 'ManceauÂ\xa0Vincent'
#  'PavlovicÂ\xa0Mateo' 'BambaÂ\xa0Abdoulaye' 'Elhadji Diaw'
#  'Pellenard Theo' 'Ait Nouri Rayan' 'FulginiÂ\xa0Angelo'
#  'ManganiÂ\xa0Thomas' 'CapelleÂ\xa0Pierrick' 'Pajot Vincent'
#  'SantamariaÂ\xa0Baptiste' 'Reine-AdÃ©laÃ¯de Jeff' "N'Doye Cheikh"
#  'El Melali Farid' 'TaitÂ\xa0Flavien' 'KangaÂ\xa0Wilfried'
#  'Bahoken Stephane' 'Manzala Harrison' 'Cristian' 'RÃºnarsson RÃºnar Alex'
#  'AllainÂ\xa0Bobby' 'LautoaÂ\xa0Wesley' 'YambÃ©rÃ©Â\xa0CÃ©dric'
#  'ChafikÂ\xa0Fouad' 'RosierÂ\xa0Valentin' 'HaddadiÂ\xa0Oussama'
#  'Coulibaly Senou' 'Aguerd Naif' 'Ciman Laurent' 'Alphonse MickaÃ«l'
#  'Bouka MoutouÂ\xa0Arnold' 'SammaritanoÂ\xa0Frederic' 'MariÃ©Â\xa0Jordan'
#  'BalmontÂ\xa0Florent' 'AmalfitanoÂ\xa0Romain' 'AbeidÂ\xa0Mehdi'
#  'Kwon Chang-Hoon' 'Gourcuff Yoann' 'Loiodice Enzo' 'SlitiÂ\xa0Naim'
#  'TavaresÂ\xa0JÃºlio' 'SaidÂ\xa0Wesley' 'Jules Keita' 'Kaba Sory'
#  'JeannotÂ\xa0Benjamin' 'KamaraÂ\xa0Bingourou' 'Kawashima Eiji'
#  'Sels Matz' 'LalaÂ\xa0Kenny' 'MartinezÂ\xa0Pablo' 'AanebaÂ\xa0Ismael'
#  'BangouÂ\xa0Duplex Tchamba' 'KonÃ© Lamine' 'Mitrovic Stefan'
#  'Carole Lionel' 'NdourÂ\xa0Abdallah' 'MartinÂ\xa0Jonas'
#  'LienardÂ\xa0Dimitri' 'CorgnetÂ\xa0Benjamin' 'CaciÂ\xa0Anthony'
#  'GonÃ§alves Anthony' 'Thomasson Adrien' 'Sissoko Ibrahima'
#  'Zemzemi Moataz' 'Zohi KÃ©vin' 'Fofana Youssouf' 'Prcic Sanjin'
#  'Grimm Jeremy' 'SaadiÂ\xa0Idriss' 'Nuno da Costa' 'Ajorque Ludovic'
#  'GurtnerÂ\xa0RÃ©gis' 'Dreyer Matthieu' 'El HajjamÂ\xa0Oualid' 'Prince'
#  'BodmerÂ\xa0Mathieu' 'AdÃ©nonÂ\xa0Khaled' 'DibassyÂ\xa0Bakaye'
#  'Lefort Jordan' 'Sy Sanasi' 'Pieters Erik' 'Krafth Emil'
#  'FofanaÂ\xa0Guessouma' 'MonconduitÂ\xa0Thomas' 'ZunguÂ\xa0Bongani'
#  'Gnahore Eddy' 'Traore Gaoussou' 'Timite Cheick' 'Ganso' 'Blin Alexis'
#  'Mendoza John Stiven' 'CornetteÂ\xa0Quentin' 'KonateÂ\xa0Moussa'
#  'Kurzawa Rafal' 'Ghoddos Saman' 'Segarel Stanley' 'Guirassy Sehrou'
#  'Otero Juan Ferney' 'Mendy Edouard' 'Carrasso Johan' 'Konan Ghislain'
#  'Abdelhamid Yunis' 'MÃ©tanire Romain' 'Fontaine Thomas' 'Engels BjÃ¶rn'
#  'Foket Thomas' 'Baba Abdul Rahman' 'Disasi Axel' 'Romao Jacques-Alaixys'
#  'Chavalerin Xavier' 'Martin Marvin' 'Cafaro Mathieu' 'Doumbia Moussa'
#  'Oudin Remi' 'Mbemba Nolan' 'Sheyi Ojo' 'Kamara Hassane' 'Dia Boulaye'
#  'Zeneli ArbÃ«r' 'Moreto Cassama' 'Dingome Tristan' 'Kyei Grejohn'
#  'Chavarria Pablo' 'Pinson Virgile' 'Suk Hyun-Jun' 'Bernadoni Paul'
#  'Valette Baptiste' 'Sourzac Martin' 'Alakouch Sofiane' 'Briancon Anthony'
#  'Landre Loick' 'Paquiez Gaetan' 'Miguel Florian' 'Lybohy Herve'
#  'Harek Fethi' 'Diallo Moustapha' 'Savanier Teji' 'Valls Theo'
#  'Faitout Maouassa' 'Bouanga Denis' 'Ferri Jordan' 'Bobichon Antonin'
#  'Sainte Luce Theo' 'Valdivia Pierrick' 'Depres Clement' 'Bozok Umut'
#  'Ripart Renaud' 'Thioub Sada' 'Alioui Rachid' 'Guillaume Baptiste']

# %%
historic = pd.read_csv('MPG_Data/historic.csv')
historic
# Out:
#        Unnamed: 0                 Nom variable  value
# 0               0       Lopes Anthony   Match1    NaN
# 1               1    Gorgelin Mathieu   Match1    6.0
# 2               2        Morel Jérémy   Match1    6.0
# 3               3              Rafael   Match1    NaN
# 4               4   Yanga-Mbiwa Mapou   Match1    NaN
# 5               5              Marçal   Match1    NaN
# 6               6             Marcelo   Match1    6.0
# 7               7       Mendy Ferland   Match1    6.0
# 8               8          Dubois Léo   Match1    5.0
# 9               9       Denayer Jason   Match1    NaN
# 10             10         Solet Oumar   Match1    NaN
# 11             11          Tete Kenny   Match1    NaN
# 12             12        Ferri Jordan   Match1    NaN
# 13             13       Tousart Lucas   Match1    7.0
# 14             14     NDombele Tanguy   Match1    6.0
# 15             15         Pape Cheikh   Match1    5.0
# 16             16      Terrier Martin   Match1    5.0
# 17             17       Aouar Houssem   Match1    5.0
# 18             18       Depay Memphis   Match1    7.5
# 19             19             Mariano   Match1    5.0
# 20             20     Traoré Bertrand   Match1    6.5
# 21             21         Fekir Nabil   Match1    NaN
# 22             22        Gouiri Amine   Match1    NaN
# 23             23      Dembele Moussa   Match1    NaN
# 24             24        Pintor Lenny   Match1    NaN
# 25             25        Fekir Yassin   Match1    NaN
# 26             26       Cornet Maxwel   Match1    4.0
# 27             27     Areola Alphonse   Match1    NaN
# 28             28    Buffon Gianluigi   Match1    6.0
# 29             29        Thiago Silva   Match1    6.0
# ...           ...                 ...      ...    ...
# 21288       21288     Dingome Tristan  Match38    5.0
# 21289       21289        Kyei Grejohn  Match38    NaN
# 21290       21290     Chavarria Pablo  Match38    6.0
# 21291       21291      Pinson Virgile  Match38    NaN
# 21292       21292        Suk Hyun-Jun  Match38    NaN
# 21293       21293      Bernadoni Paul  Match38    5.0
# 21294       21294    Valette Baptiste  Match38    NaN
# 21295       21295      Sourzac Martin  Match38    NaN
# 21296       21296    Alakouch Sofiane  Match38    NaN
# 21297       21297    Briancon Anthony  Match38    4.5
# 21298       21298        Landre Loick  Match38    NaN
# 21299       21299      Paquiez Gaetan  Match38    4.5
# 21300       21300      Miguel Florian  Match38    5.5
# 21301       21301        Lybohy Herve  Match38    NaN
# 21302       21302         Harek Fethi  Match38    NaN
# 21303       21303    Diallo Moustapha  Match38    NaN
# 21304       21304       Savanier Teji  Match38    6.0
# 21305       21305          Valls Theo  Match38    NaN
# 21306       21306    Faitout Maouassa  Match38    2.5
# 21307       21307       Bouanga Denis  Match38    4.0
# 21308       21308        Ferri Jordan  Match38    6.0
# 21309       21309    Bobichon Antonin  Match38    7.0
# 21310       21310    Sainte Luce Theo  Match38    NaN
# 21311       21311   Valdivia Pierrick  Match38    NaN
# 21312       21312      Depres Clement  Match38    NaN
# 21313       21313          Bozok Umut  Match38    NaN
# 21314       21314       Ripart Renaud  Match38    6.5
# 21315       21315         Thioub Sada  Match38    5.0
# 21316       21316       Alioui Rachid  Match38    NaN
# 21317       21317  Guillaume Baptiste  Match38    4.0
#
# [21318 rows x 4 columns]
