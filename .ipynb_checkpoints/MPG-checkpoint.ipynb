# %%
import pandas as pd
import numpy
import xlrd
import re
import numpy as np
import matplotlib.pyplot as plt
import data

pd.set_option('display.max_columns', 500)

# %%
players = pd.read_csv('MPG_Data/players.csv',encoding = 'latin-1')

# %%
team = data.MpgData().Players().get_player_stats('Rafael')
print(team)
players = data.MpgData().Players().players
#players
# Out:
# [P('Team : OL'), P('\nPosition : D'), P('\nMean performance : 4.972222222222221'), P('\nGoals : (-1)'), P('\nVariance : 0.6021241830065359'), P('\nPrice : 8.0'), P('\nRegular : 11.0')]
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\core\generic.py:6130: SettingWithCopyWarning:
#
#
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
data.MpgData().get_data_files()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-5-e6fdc58193cf> in <module>
# ----> 1 data.Historic().get_data_files()
#
# AttributeError: module 'data' has no attribute 'Historic'

# %%
print(players['Nom'].replace('\xa0',' '))
# Out:
# 0           Lopes Anthony
# 1        Gorgelin Mathieu
# 2            Morel Jérémy
# 3                  Rafael
# 4       Yanga-Mbiwa Mapou
# 5                  Marçal
# 6                 Marcelo
# 7           Mendy Ferland
# 8              Dubois Léo
# 9           Denayer Jason
# 10            Solet Oumar
# 11             Tete Kenny
# 12           Ferri Jordan
# 13          Tousart Lucas
# 14        NDombele Tanguy
# 15            Pape Cheikh
# 16         Terrier Martin
# 17          Aouar Houssem
# 18          Depay Memphis
# 19                Mariano
# 20        Traoré Bertrand
# 21            Fekir Nabil
# 22           Gouiri Amine
# 23         Dembele Moussa
# 24           Pintor Lenny
# 25           Fekir Yassin
# 26          Cornet Maxwel
# 27        Areola Alphonse
# 28       Buffon Gianluigi
# 29           Thiago Silva
#               ...
# 531       Dingome Tristan
# 532          Kyei Grejohn
# 533       Chavarria Pablo
# 534        Pinson Virgile
# 535          Suk Hyun-Jun
# ...

# %%
historic = pd.read_csv('MPG_Data/historic.csv',encoding = 'latin-1')
historic
# Out:
#        Unnamed: 0                 Nom variable  value
# 0               0      LopesÂ Anthony   Match1    NaN
# 1               1   GorgelinÂ Mathieu   Match1    6.0
# 2               2     MorelÂ JÃ©rÃ©my   Match1    6.0
# 3               3              Rafael   Match1    NaN
# 4               4  Yanga-MbiwaÂ Mapou   Match1    NaN
# 5               5             MarÃ§al   Match1    NaN
# 6               6             Marcelo   Match1    6.0
# 7               7      MendyÂ Ferland   Match1    6.0
# 8               8         Dubois LÃ©o   Match1    5.0
# 9               9       Denayer Jason   Match1    NaN
# 10             10         Solet Oumar   Match1    NaN
# 11             11         TeteÂ Kenny   Match1    NaN
# 12             12       FerriÂ Jordan   Match1    NaN
# 13             13      TousartÂ Lucas   Match1    7.0
# 14             14    NDombeleÂ Tanguy   Match1    6.0
# 15             15         Pape Cheikh   Match1    5.0
# ...

# %%
import data
print(data.MpgData().Historic().historic['Nom'])
print(data.MpgData().Historic().from_player('Rafael'))
print(data.MpgData().Historic().performance_graph('Rafael'))
# Out:
# 0             Lopes Anthony
# 1          Gorgelin Mathieu
# 2              Morel Jérémy
# 3                    Rafael
# 4         Yanga-Mbiwa Mapou
# 5                    Marçal
# 6                   Marcelo
# 7             Mendy Ferland
# 8                Dubois Léo
# 9             Denayer Jason
# 10              Solet Oumar
# 11               Tete Kenny
# 12             Ferri Jordan
# 13            Tousart Lucas
# 14          NDombele Tanguy
# 15              Pape Cheikh
# 16           Terrier Martin
# 17            Aouar Houssem
# 18            Depay Memphis
# 19                  Mariano
# 20          Traoré Bertrand
# 21              Fekir Nabil
# 22             Gouiri Amine
# 23           Dembele Moussa
# 24             Pintor Lenny
# 25             Fekir Yassin
# 26            Cornet Maxwel
# 27          Areola Alphonse
# 28         Buffon Gianluigi
# 29             Thiago Silva
#                 ...
# 21288       Dingome Tristan
# 21289          Kyei Grejohn
# ...

# %%
df.head()
# Out:
#    Unnamed: 0                Nom variable  value
# 0           0      Lopes Anthony   Match1    NaN
# 1           1   Gorgelin Mathieu   Match1    6.0
# 2           2       Morel Jérémy   Match1    6.0
# 3           3             Rafael   Match1    NaN
# 4           4  Yanga-Mbiwa Mapou   Match1    NaN

# %%
import data
plays = data.MpgData().Players().get_list()
plays
# Out:
# [{'label': 'Lopes Anthony', 'value': 'Lopes Anthony'},
#  {'label': 'Gorgelin Mathieu', 'value': 'Gorgelin Mathieu'},
#  {'label': 'Morel Jérémy', 'value': 'Morel Jérémy'},
#  {'label': 'Rafael', 'value': 'Rafael'},
#  {'label': 'Yanga-Mbiwa Mapou', 'value': 'Yanga-Mbiwa Mapou'},
#  {'label': 'Marçal', 'value': 'Marçal'},
#  {'label': 'Marcelo', 'value': 'Marcelo'},
#  {'label': 'Mendy Ferland', 'value': 'Mendy Ferland'},
#  {'label': 'Dubois Léo', 'value': 'Dubois Léo'},
#  {'label': 'Denayer Jason', 'value': 'Denayer Jason'},
#  {'label': 'Solet Oumar', 'value': 'Solet Oumar'},
#  {'label': 'Tete Kenny', 'value': 'Tete Kenny'},
#  {'label': 'Ferri Jordan', 'value': 'Ferri Jordan'},
#  {'label': 'Tousart Lucas', 'value': 'Tousart Lucas'},
#  {'label': 'NDombele Tanguy', 'value': 'NDombele Tanguy'},
#  {'label': 'Pape Cheikh', 'value': 'Pape Cheikh'},
#  {'label': 'Terrier Martin', 'value': 'Terrier Martin'},
#  {'label': 'Aouar Houssem', 'value': 'Aouar Houssem'},
# ...

# %%
import data
import pandas as pd

historic = pd.read_csv('MPG_Data/historic.csv',encoding = 'latin-1')
data.MpgData().Historic().performance_graph('Rafael')

pg = data.MpgData().Historic().from_player('Rafael')
graph = data.MpgData().Historic().performance_graph('Rafael')
print(graph)
print('_____')
x = data.MpgData().Historic().from_player('Rafael')['variable']
print(type(x))
# Out:
# {'data': [{'x': 3            3
# 564        564
# 1125      1125
# 1686      1686
# 2247      2247
# 2808      2808
# 3369      3369
# 3930      3930
# 4491      4491
# 5052      5052
# 5613      5613
# 6174      6174
# 6735      6735
# 7296      7296
# 7857      7857
# 8418      8418
# 8979      8979
# 9540      9540
# 10101    10101
# 10662    10662
# 11223    11223
# 11784    11784
# 12345    12345
# 12906    12906
# 13467    13467
# 14028    14028
# 14589    14589
# 15150    15150
# 15711    15711
# 16272    16272
# 16833    16833
# 17394    17394
# 17955    17955
# 18516    18516
# 19077    19077
# 19638    19638
# 20199    20199
# 20760    20760
# Name: Unnamed: 0, dtype: int64, 'y': 3        NaN
# 564      5.0
# 1125     5.5
# 1686     5.0
# 2247     4.5
# 2808     NaN
# 3369     6.5
# 3930     5.0
# 4491     5.5
# 5052     NaN
# 5613     5.0
# 6174     5.0
# 6735     5.0
# 7296     4.5
# 7857     NaN
# 8418     NaN
# 8979     NaN
# 9540     NaN
# 10101    NaN
# 10662    NaN
# ...
